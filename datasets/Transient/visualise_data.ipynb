# %%
import matplotlib.pyplot as plt
import numpy as np

import generate_data

# %%
example_feature, example_label = generate_data.gen_data()
plt.plot(example_feature.squeeze())
plt.title(f'Label: {example_label}')
plt.ylim(-2, 2)
plt.show()
